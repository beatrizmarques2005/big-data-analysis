# %% [markdown]
# <font size=10>**MONGODB CONNECTION**</font> <a class="anchor" id='title'></a>
#
# **Bachelor's in Data Science - NOVA IMS (25/26)**
#
# **Group 8**
# - Beatriz Marques 20231605
# - David Carrilho 20231693
# - Duarte Fernandes 20231619
# - Filipe Caçador 20231707
# - Mariana Calais-Pedro 20231641
#
# *This notebook is designed to first configure the MongoDB Atlas connection, then insert the required datasets.*

# %% [markdown]
# <font color='#BFD72' size=6>**TABLE OF CONTENTS**</font> <a class="anchor" id='toc'></a>
# - [1. Imports](#1)
# - [2. Set MongoDB Atlas connection](#2)
# - [3. Insert Databases into MongoDB](#3)

# %% [markdown]
# # <font color='#BFD72F' size=6>**1. Imports**</font> <a class="anchor" id="1"></a>
#
# [Back to TOC](#toc)

# %%
import os
from pyspark.sql import SparkSession
import pymongo

# %pip install pyspark pymongo

# Install Java 17
# !sudo apt-get update
# !sudo apt-get install -y openjdk-17-jdk-headless
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Hit:1 https://download.docker.com/linux/ubuntu noble InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble InRelease
# Hit:4 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:5 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-backports InRelease
# Hit:6 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-security InRelease
# Hit:7 https://archive.ubuntu.com/ubuntu noble InRelease
# Hit:8 https://archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:9 https://archive.ubuntu.com/ubuntu noble-backports InRelease
# Hit:10 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Get:11 http://deb.wakemeops.com/wakemeops stable InRelease [50.5 kB]
# Hit:12 https://security.ubuntu.com/ubuntu noble-security InRelease
# Get:13 http://deb.wakemeops.com/wakemeops stable/dev amd64 Packages [151 kB]
# ...

# %%
# Set JAVA_HOME to Java 17
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"

# %%
spark = SparkSession \
    .builder \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.13:10.5.0") \
    .appName("PySpark MongoDB") \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/system/conda/miniconda3/envs/cloudspace/lib/python3.12/site-packages/pyspark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/zeus/.ivy2.5.2/cache
# The jars for the packages stored in: /home/zeus/.ivy2.5.2/jars
# org.mongodb.spark#mongo-spark-connector_2.13 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-7a82fc38-26a0-451f-8cf7-4735330b6364;1.0
# 	confs: [default]
# 	found org.mongodb.spark#mongo-spark-connector_2.13;10.5.0 in central
# 	found org.mongodb#mongodb-driver-sync;5.1.4 in central
# 	[5.1.4] org.mongodb#mongodb-driver-sync;[5.1.1,5.1.99)
# 	found org.mongodb#bson;5.1.4 in central
# 	found org.mongodb#mongodb-driver-core;5.1.4 in central
# 	found org.mongodb#bson-record-codec;5.1.4 in central
# :: resolution report :: resolve 935ms :: artifacts dl 7ms
# 	:: modules in use:
# ...

# %%
sc = spark.sparkContext

# %%
# %%sh
# spark-sql --version
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 4.0.1
#       /_/
#
# Using Scala version 2.13.16, OpenJDK 64-Bit Server VM, 17.0.16
# Branch HEAD
# Compiled by user runner on 2025-09-02T03:10:51Z
# Revision 29434ea766b0fc3c3bf6eaadb43a8f931133649e
# Url https://github.com/apache/spark
# Type --help for more information.

# %% [markdown]
# # <font color='#BFD72F' size=6>**2. Set MongoDB Atlas connection**</font> <a class="anchor" id="2"></a>
#
# [Back to TOC](#toc)

# %%
username = os.getenv("PROJECT_USERNAME")
password = os.getenv("PROJECT_PASSWORD")

# %%
print(username)
# Out:
# Grupo_08

# %%
# Set MongoDB Atlas connection parameters
mongo_uri = f"mongodb+srv://{username}:{password}@cluster0.dtgbnim.mongodb.net/?appName=Cluster0" 
databaseBank = "Bank_Marketing"
collection_name_Bank = "Bank_Marketing_collection"

databaseBooks = "Books"
collection_name_Books = "BooksData"

# %%
# We will instantiate the client
client = pymongo.MongoClient(mongo_uri)

# %%
# Here, we create a new database and collection
db1 = client[databaseBooks]
collection1 = db1[collection_name_Books]

db2 = client[databaseBank]
collection2 = db2[collection_name_Bank]

# %%
client.list_database_names()
# Out:
# ['Bank_Marketing', 'BigData_Project', 'admin', 'local']

# %% [markdown]
# # <font color='#BFD72F' size=6>**3. Insert Databases into MongoDB**</font> <a class="anchor" id="3"></a>
#
# [Back to TOC](#toc)

# %%
'''import csv

data_to_insert = []

# Try reading with CP949 (Korean Windows encoding)
with open("/teamspace/studios/this_studio/big-data-analysis/data/raw/Bank Marketing.csv", 'r', encoding='cp949') as f:
    reader = csv.DictReader(f)
    for row in reader:
        data_to_insert.append(row)

# Insert into MongoDB
if data_to_insert:
        collection2.insert_many(data_to_insert)
        print(f"✅ Inserted {len(data_to_insert)} records successfully.")
else:
    print("⚠️ No data found in the CSV file.")

client.close()'''
# Out:
# 'import csv\n\ndata_to_insert = []\n\n# Try reading with CP949 (Korean Windows encoding)\nwith open("/teamspace/studios/this_studio/big-data-analysis/data/raw/Bank Marketing.csv", \'r\', encoding=\'cp949\') as f:\n    reader = csv.DictReader(f)\n    for row in reader:\n        data_to_insert.append(row)\n\n# Insert into MongoDB\nif data_to_insert:\n        collection2.insert_many(data_to_insert)\n        print(f"✅ Inserted {len(data_to_insert)} records successfully.")\nelse:\n    print("⚠️ No data found in the CSV file.")\n\nclient.close()'

# %%
from tqdm import tqdm 
import pandas as pd

# Try reading with CP949 (Korean Windows encoding)
csv_path = "hf://datasets/BrightData/Goodreads-Books/Goodreads-Books.csv"
chunk_size = 10000  # adjust based on your system

total_inserted = 0

for chunk in tqdm(pd.read_csv(csv_path, chunksize=chunk_size), desc="📚 Inserting chunks"):
    # Convert each chunk (DataFrame) to a list of dicts
    records = chunk.to_dict(orient="records")

        # Insert into MongoDB
    if records:
        collection1.insert_many(records)
        total_inserted += len(records)

print(f"✅ Done! Inserted {total_inserted} records into MongoDB collection 'GoodreadsBooks'.")

client.close()
# Out:
# 📚 Inserting chunks: 34it [03:18,  5.83s/it]
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[13], line 16
#      14         # Insert into MongoDB
#      15     if records:
# ---> 16         collection1.insert_many(records)
#      17         total_inserted += len(records)
#      19 print(f"✅ Done! Inserted {total_inserted} records into MongoDB collection 'GoodreadsBooks'.")
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# ...
