# %% [markdown]
# <font size=10>**GRAPH FRAMES**</font> <a class="anchor" id='title'></a>
#
#
# *«notebook description»*

# %% [markdown]
# <font color='#BFD72' size=6>**TABLE OF CONTENTS**</font> <a class="anchor" id='toc'></a>
# - [1. Imports](#P1)
# - [2. Data](#P2)
# - [3. Graph Frames](#P3)

# %% [markdown]
# # <font color='#BFD72F' size=6>**1. Imports**</font> <a class="anchor" id="P1"></a>
#
# [Back to TOC](#toc)

# %%
import warnings
# %load_ext autoreload
# %autoreload 2

warnings.filterwarnings('ignore')

# %%
import sys
import os
import pandas as pd

# Get the absolute path of the source_code folder
source_code_path = os.path.abspath('../source')

# Add the source_code folder to sys.path
if source_code_path not in sys.path:
    sys.path.append(source_code_path)

from spark_utils import *

# %% [markdown]
# # <font color='#BFD72F' size=6>**2. Data**</font> <a class="anchor" id="P2"></a>
#
# [Back to TOC](#toc)

# %%
books_original = pd.read_csv("hf://datasets/BrightData/Goodreads-Books/Goodreads-Books.csv")

# %%
books_original.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/1047836.Ho...
# 1  https://www.goodreads.com/book/show/4089333-au...
# 2  https://www.goodreads.com/book/show/26764878-m...
# 3  https://www.goodreads.com/book/show/23656944-z...
# 4  https://www.goodreads.com/book/show/26761586-t...
#
#                                         id  \
# 0  1047836.Horror_Film_Directors_1931_1990
# 1        4089333-australian-urban-planning
# 2             26764878-morgen-ohne-gestern
# 3    23656944-zen-and-the-art-of-recording
# 4       26761586-the-big-book-of-codewords
#
#                                                 name               author  \
# 0                   Horror Film Directors, 1931-1990   ["Dennis Fischer"]
# 1  Australian Urban Planning: New Challenges, New...  ["Brendan Gleeson"]
# 2                         Morgen ohne gestern: Roman   ["Regina Nössler"]
# 3                       Zen and the Art of Recording         ["Mixerman"]
# 4                          The Big Book Of Codewords   ["Parragon Books"]
#
#    star_rating  num_ratings  num_reviews  \
# 0         4.29          7.0          NaN
# 1         3.00          1.0          NaN
# 2         3.00          2.0          NaN
# 3         4.19         88.0          4.0
# 4         4.50          6.0          NaN
#
#                                              summary                  genres  \
# 0  An exhaustive study of the major directors of ...                     NaN
# 1  Designed for use by academics, students, plann...                     NaN
# 2  Christine Hoffmann wacht eines Morgens im Kran...                     NaN
# 3  In this book, the third in the Zen and the Art...  ["Music","Nonfiction"]
# 4            500 codeword puzzles in one great book!                     NaN
#
#   first_published                                       about_author  \
# 0       11/1/1991           {"name":"Dennis Fischer","num_books":14}
# 1        2/1/2000          {"name":"Brendan Gleeson","num_books":28}
# 2       9/18/2015  {"name":"Regina Nössler","num_books":28,"num_f...
# 3       10/1/2014  {"name":"Mixerman","num_books":15,"num_followe...
# 4        9/5/2015  {"name":"Parragon Books","num_books":6068,"num...
#
#                                    community_reviews kindle_price
# 0  {"1_stars":{"reviews_num":0,"reviews_percentag...          NaN
# 1  {"1_stars":{"reviews_num":0,"reviews_percentag...          NaN
# 2  {"1_stars":{"reviews_num":1,"reviews_percentag...     "$10.89"
# 3  {"1_stars":{"reviews_num":0,"reviews_percentag...     "$24.09"
# 4  {"1_stars":{"reviews_num":0,"reviews_percentag...          NaN

# %%
books = books_original.copy()

# %%
seoul_bikes_original = pd.read_csv(
    "../data/raw/SeoulBikeData.csv",
    encoding="latin1"     # same as ISO-8859-1
)

# %%
seoul_bikes_original.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday
#
#   Functioning Day
# 0             Yes
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes

# %%
seoul_bikes = seoul_bikes_original.copy()

# %% [markdown]
# # <font color='#BFD72F' size=6>**3. Graph Frames**</font> <a class="anchor" id="P3"></a>
#
# [Back to TOC](#toc)
