# %% [markdown]
# <font size=10>**EXPLORATION/PREPROCESSING**</font> <a class="anchor" id='title'></a>
#
# **Bachelor's in Data Science - NOVA IMS (25/26)**
#
# **Project**: [*Goodreads-Books - Apply graph analysis*](https://huggingface.co/datasets/BrightData/Goodreads-Books)
#
# **Group 8**
# - Beatriz Marques 20231605
# - David Carrilho 20231693
# - Duarte Fernandes 20231619
# - Filipe Caçador 20231707
# - Mariana Calais-Pedro 20231641
#
# *«notebook description»*

# %% [markdown]
# <font color='#BFD72' size=6>**TABLE OF CONTENTS**</font> <a class="anchor" id='toc'></a>
# - [1. Imports](#1)
# - [2. Data Integration](#2)
#     - [2.1 Cleaning and Normalizing MongoDB-Exported Fields in a PySpark DataFrame](#2_1)
#     - [2.2 Correcting the dataypes of some columns](#2_2)
#     - [2.3 Transform genres to array](#2_3)
#     - [2.4 Filtering our dataset between 1500 and 2025](#2_4)
# - [3. Data Exploration](#3)

# %% [markdown]
# # <font color='#BFD72F' size=6>**1. Imports**</font> <a class="anchor" id="1"></a>
#
# [Back to TOC](#toc)

# %%
# %pip install pyspark pymongo
# Out:
# Requirement already satisfied: pyspark in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (3.5.0)
# Requirement already satisfied: pymongo in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (4.15.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pyspark) (0.10.9.7)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pymongo) (2.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install Java 17
# !sudo apt-get update
# !sudo apt-get install -y openjdk-17-jdk-headless
# Out:
# Hit:1 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble InRelease
# Hit:2 https://download.docker.com/linux/ubuntu noble InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:5 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-backports InRelease
# Hit:6 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble-security InRelease
# Hit:7 https://security.ubuntu.com/ubuntu noble-security InRelease
# Hit:8 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Hit:9 http://deb.wakemeops.com/wakemeops stable InRelease
# Hit:10 https://archive.ubuntu.com/ubuntu noble InRelease
# Hit:11 https://archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:12 https://archive.ubuntu.com/ubuntu noble-backports InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# openjdk-17-jdk-headless is already the newest version (17.0.17+10-1~24.04).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.

# %%
# %pip install graphframes-py==0.10.0
# Out:
# Requirement already satisfied: graphframes-py==0.10.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (0.10.0)
# Requirement already satisfied: nose==1.3.7 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from graphframes-py==0.10.0) (1.3.7)
# Requirement already satisfied: numpy>=1.7 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from graphframes-py==0.10.0) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Set JAVA_HOME to Java 17
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"

# %%
from pyspark.sql import SparkSession
spark = (
    SparkSession.builder
    .appName("PySpark MongoDB + GraphFrames")
    .master("local[*]")  # It's cleaner to use .master() method
    .config("spark.sql.broadcastTimeout", "3600")
    .config("spark.sql.shuffle.partitions", "10")  # <--- Moved inside
    .config(
        "spark.jars.packages",
        ",".join([
            "org.mongodb.spark:mongo-spark-connector_2.12:10.5.0",
            "io.graphframes:graphframes-spark3_2.12:0.10.0"
        ])
    )
    .getOrCreate()
)
# Out:
# :: loading settings :: url = jar:file:/system/conda/miniconda3/envs/cloudspace/lib/python3.12/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/zeus/.ivy2/cache
# The jars for the packages stored in: /home/zeus/.ivy2/jars
# org.mongodb.spark#mongo-spark-connector_2.12 added as a dependency
# io.graphframes#graphframes-spark3_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-3acea89e-f40b-4ae3-81f8-9ab20091363a;1.0
# 	confs: [default]
# 	found org.mongodb.spark#mongo-spark-connector_2.12;10.5.0 in central
# 	found org.mongodb#mongodb-driver-sync;5.1.4 in central
# 	[5.1.4] org.mongodb#mongodb-driver-sync;[5.1.1,5.1.99)
# 	found org.mongodb#bson;5.1.4 in central
# 	found org.mongodb#mongodb-driver-core;5.1.4 in central
# 	found org.mongodb#bson-record-codec;5.1.4 in central
# 	found io.graphframes#graphframes-spark3_2.12;0.10.0 in central
# 	found io.graphframes#graphframes-graphx-spark3_2.12;0.10.0 in central
# :: resolution report :: resolve 1023ms :: artifacts dl 9ms
# 	:: modules in use:
# 	io.graphframes#graphframes-graphx-spark3_2.12;0.10.0 from central in [default]
# 	io.graphframes#graphframes-spark3_2.12;0.10.0 from central in [default]
# 	org.mongodb#bson;5.1.4 from central in [default]
# 	org.mongodb#bson-record-codec;5.1.4 from central in [default]
# 	org.mongodb#mongodb-driver-core;5.1.4 from central in [default]
# 	org.mongodb#mongodb-driver-sync;5.1.4 from central in [default]
# 	org.mongodb.spark#mongo-spark-connector_2.12;10.5.0 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   7   |   1   |   0   |   0   ||   7   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-3acea89e-f40b-4ae3-81f8-9ab20091363a
# 	confs: [default]
# 	0 artifacts copied, 7 already retrieved (0kB/5ms)
# 25/12/11 12:45:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
print(spark.sparkContext._jsc.sc().listJars())
# Out:
# Vector(spark://ip-10-192-12-236.ec2.internal:50225/jars/org.mongodb_bson-5.1.4.jar, spark://ip-10-192-12-236.ec2.internal:50225/jars/org.mongodb.spark_mongo-spark-connector_2.12-10.5.0.jar, spark://ip-10-192-12-236.ec2.internal:50225/jars/org.mongodb_mongodb-driver-core-5.1.4.jar, spark://ip-10-192-12-236.ec2.internal:50225/jars/org.mongodb_bson-record-codec-5.1.4.jar, spark://ip-10-192-12-236.ec2.internal:50225/jars/io.graphframes_graphframes-graphx-spark3_2.12-0.10.0.jar, spark://ip-10-192-12-236.ec2.internal:50225/jars/io.graphframes_graphframes-spark3_2.12-0.10.0.jar, spark://ip-10-192-12-236.ec2.internal:50225/jars/org.mongodb_mongodb-driver-sync-5.1.4.jar)

# %%
sc=spark.sparkContext
sc.setCheckpointDir("/tmp/graphframes-checkpoint")

# %%
# %%sh
# spark-sql --version
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 3.5.0
#       /_/
#
# Using Scala version 2.12.18, OpenJDK 64-Bit Server VM, 17.0.17
# Branch HEAD
# Compiled by user ubuntu on 2023-09-09T01:53:20Z
# Revision ce5ddad990373636e94071e7cef2f31021add07b
# Url https://github.com/apache/spark
# Type --help for more information.

# %%
import warnings
# %load_ext autoreload
# %autoreload 2

warnings.filterwarnings('ignore')

# %%
# !pip install graphframes
# Out:
# Requirement already satisfied: graphframes in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (0.6)
# Requirement already satisfied: numpy in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from graphframes) (1.26.4)
# Requirement already satisfied: nose in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from graphframes) (1.3.7)

# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt

# Get the absolute path of the source_code folder
source_code_path = os.path.abspath('../../source')

# Add the source_code folder to sys.path
if source_code_path not in sys.path:
    sys.path.append(source_code_path)

from spark_utils import *
from preprocessing import *
from visualizations import *
from pyspark.sql import functions as F
from pyspark import StorageLevel
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
from pyspark.sql.functions import col, when
from graphframes import GraphFrame

# %% [markdown]
# # <font color='#BFD72F' size=6>**2. Data Integration**</font> <a class="anchor" id="2"></a>
#
# [Back to TOC](#toc)

# %%
username = os.getenv("PROJECT_USERNAME")
password = os.getenv("PROJECT_PASSWORD")
print(username)
print(password)
# Out:
# Grupo_08
# Grupo_08

# %%
import pymongo
# Set MongoDB Atlas connection parameters
mongo_uri = f"""mongodb+srv://{username}:{password}@cluster0.dtgbnim.mongodb.net/?appName=Cluster0"""

# %%
client = pymongo.MongoClient(mongo_uri)
client.list_database_names()
# Out:
# ['Bank_Marketing', 'BigData_Project', 'Books', 'admin', 'local']

# %%
database_name = "Books"
collection_name = "BooksData"

# %%
database = client[database_name]
collection = database[collection_name]

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('69122a00adb7d57eb76f21b5'),
#  'url': 'https://www.goodreads.com/book/show/1047836.Horror_Film_Directors_1931_1990',
#  'id': '1047836.Horror_Film_Directors_1931_1990',
#  'name': 'Horror Film Directors, 1931-1990',
#  'author': '["Dennis Fischer"]',
#  'star_rating': 4.29,
#  'num_ratings': 7,
#  'num_reviews': nan,
#  'summary': 'An exhaustive study of the major directors of horror films in the past six decades, a genre always popular but often critically snubbed. For each director there is a complete filmography including television work, a career summary, critical assessment, and behind-the-scenes production information. The book covers not only films both old and new, but also directors from Italy, Spain, Australia, Belgium, and elsewhere. Fifty directors are covered in depth, but there is an additional section on the hopeless, the obscure, the promising, and the up-and-coming.',
#  'genres': nan,
#  'first_published': '11/1/1991',
#  'about_author': '{"name":"Dennis Fischer","num_books":14}',
#  'community_reviews': '{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":1,"reviews_percentage":14},"4_stars":{"reviews_num":3,"reviews_percentage":42},"5_stars":{"reviews_num":3,"reviews_percentage":42}}',
#  'kindle_price': nan}

# %%
# 1) Kill the existing session (it holds the bad URI)
try:
    spark.stop()
except:
    pass

# %%
# 2) Start a fresh session with the correct Atlas SRV URI

spark = (SparkSession.builder
    .config("spark.mongodb.read.connection.uri", mongo_uri)
    .config("spark.mongodb.write.connection.uri", mongo_uri)
    .getOrCreate())

# %%
# 3) Read: pass database & collection explicitly
books_original = (spark.read.format("mongodb")
      .option("database", database_name)
      .option("collection", collection_name)
      .load())

# %% [markdown]
# # <font color='#BFD72F' size=6>**2. Data Exploration**</font> <a class="anchor" id="2"></a>
#
# [Back to TOC](#toc)

# %%
'''print("Spark sees read URI:", spark.conf.get("spark.mongodb.read.connection.uri", "MISSING"))
books_original.printSchema()
print("rows:", books_original.count())'''
# Out:
# 'print("Spark sees read URI:", spark.conf.get("spark.mongodb.read.connection.uri", "MISSING"))\nbooks_original.printSchema()\nprint("rows:", books_original.count())'

# %%
# Making a copy to save the original file
books = books_original.alias('books')

# %%
books.show(5, truncate = False)
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +------------------------+---------------------------------------------------------------+-------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+------------------------+---------------------------------------+------------------------+------------------------------------------------------+-----------+-----------+-----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------+
# |_id                     |about_author                                                   |author             |community_reviews                                                                                                                                                                                                                                                     |first_published|genres                  |id                                     |kindle_price            |name                                                  |num_ratings|num_reviews|star_rating|summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |url                                                                        |
# +------------------------+---------------------------------------------------------------+-------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+------------------------+---------------------------------------+------------------------+------------------------------------------------------+-----------+-----------+-----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------+
# |69122a00adb7d57eb76f21b5|{"name":"Dennis Fischer","num_books":14}                       |["Dennis Fischer"] |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":1,"reviews_percentage":14},"4_stars":{"reviews_num":3,"reviews_percentage":42},"5_stars":{"reviews_num":3,"reviews_percentage":42}}   |11/1/1991      |{"$numberDouble": "NaN"}|1047836.Horror_Film_Directors_1931_1990|{"$numberDouble": "NaN"}|Horror Film Directors, 1931-1990                      |7          |NaN        |4.29       |An exhaustive study of the major directors of horror films in the past six decades, a genre always popular but often critically snubbed. For each director there is a complete filmography including television work, a career summary, critical assessment, and behind-the-scenes production information. The book covers not only films both old and new, but also directors from Italy, Spain, Australia, Belgium, and elsewhere. Fifty directors are covered in depth, but there is an additional section on the hopeless, the obscure, the promising, and the up-and-coming.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |https://www.goodreads.com/book/show/1047836.Horror_Film_Directors_1931_1990|
# |69122a00adb7d57eb76f21b6|{"name":"Brendan Gleeson","num_books":28}                      |["Brendan Gleeson"]|{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":1,"reviews_percentage":100},"4_stars":{"reviews_num":0,"reviews_percentage":0},"5_stars":{"reviews_num":0,"reviews_percentage":0}}    |2/1/2000       |{"$numberDouble": "NaN"}|4089333-australian-urban-planning      |{"$numberDouble": "NaN"}|Australian Urban Planning: New Challenges, New Agendas|1          |NaN        |3.0        |Designed for use by academics, students, planning professionals, and anyone who takes an interest in the development of cities, this timely book explains the changes that have transformed planning in Australia and reinstates the need for planning based on principles that foreground social inclusion and ecological sustainability.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |https://www.goodreads.com/book/show/4089333-australian-urban-planning      |
# |69122a00adb7d57eb76f21b7|{"name":"Regina Nössler","num_books":28,"num_followers":"1"}   |["Regina Nössler"] |{"1_stars":{"reviews_num":1,"reviews_percentage":50},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":0,"reviews_percentage":0},"4_stars":{"reviews_num":0,"reviews_percentage":0},"5_stars":{"reviews_num":1,"reviews_percentage":50}}    |9/18/2015      |{"$numberDouble": "NaN"}|26764878-morgen-ohne-gestern           |"$10.89"                |Morgen ohne gestern: Roman                            |2          |NaN        |3.0        |Christine Hoffmann wacht eines Morgens im Krankenhaus auf und hat ihr Leben vergessen. Ihre Eltern sind ihr ebenso fremd wie ihre beste Freundin, selbstihre Lebensgefährtin Marion erkennt sie nicht wieder. Christines Alltag wird zu einem Puzzle, das sie aus Erzählungen und Erinnerungsblitzen neu zusammensetzen muss.Wer war sie, wer ist sie und weshalb weiß sie es nicht mehr? Was genau ist mit ihr passiert? Hat sie wirklich acht glückliche Jahre mit Marion verbracht? Wem kann sie  ihrer Intuition oder denen, die scheinbar das Beste für sie wollen? Gibt es etwas, das man ihr verheimlicht?Während Christine versucht, alte Liebe mühsam neu zu erlernen, begegnet sie Eva. Mühelos verliebt sie sich und erinnert sich plötzlich an Glück. Doch kann sie es auch zulassen? Der neue Beziehungsthriller von Regina Nössler verfolgt stilsicher eine junge Frau auf der Suche nach wahren Gefühlen und sich selbst. Eindringlich und außergewöhnlich spannend erzählt.                                                                                                                                              |https://www.goodreads.com/book/show/26764878-morgen-ohne-gestern           |
# |69122a00adb7d57eb76f21b8|{"name":"Mixerman","num_books":15,"num_followers":"36"}        |["Mixerman"]       |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":6,"reviews_percentage":6},"3_stars":{"reviews_num":12,"reviews_percentage":13},"4_stars":{"reviews_num":29,"reviews_percentage":32},"5_stars":{"reviews_num":41,"reviews_percentage":46}}|10/1/2014      |["Music","Nonfiction"]  |23656944-zen-and-the-art-of-recording  |"$24.09"                |Zen and the Art of Recording                          |88         |4.0        |4.19       |In this book, the third in the Zen and the Art Of series, Mixerman distills the inescapable technical realities of recording down to understandable and practical terms. Whether musician or self-taught recordist, whether at home or in a full-blown studio complex, you'll discover a definitive blueprint for recording within the current realities of the business, without ever losing focus on the core consideration--the music itself. \r\n\r\nAs Mixerman writes: "The moment you start to think in musical terms, your recordings will improve a hundredfold." This enhanced multimedia e-book edition brings recordists deeper into the concepts covered in the text. It features over an hour's worth of supplemental videos in which Mixerman demonstrates various recording techniques in a number of recording spaces. The clips provide invaluable insight into what to listen for when choosing gear and placing mics, and Mixerman walks us through all of this in well over an hour of clips. This multimedia eBook is an absolute must-have for anyone who enjoys recording music and wants to get better doing it.|https://www.goodreads.com/book/show/23656944-zen-and-the-art-of-recording  |
# |69122a00adb7d57eb76f21b9|{"name":"Parragon Books","num_books":6068,"num_followers":"67"}|["Parragon Books"] |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":1,"reviews_percentage":16},"4_stars":{"reviews_num":1,"reviews_percentage":16},"5_stars":{"reviews_num":4,"reviews_percentage":66}}   |9/5/2015       |{"$numberDouble": "NaN"}|26761586-the-big-book-of-codewords     |{"$numberDouble": "NaN"}|The Big Book Of Codewords                             |6          |NaN        |4.5        |500 codeword puzzles in one great book!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |https://www.goodreads.com/book/show/26761586-the-big-book-of-codewords     |
# +------------------------+---------------------------------------------------------------+-------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+------------------------+---------------------------------------+------------------------+------------------------------------------------------+-----------+-----------+-----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------+
# only showing top 5 rows

# %%
books.columns
# Out:
# ['_id',
#  'about_author',
#  'author',
#  'community_reviews',
#  'first_published',
#  'genres',
#  'id',
#  'kindle_price',
#  'name',
#  'num_ratings',
#  'num_reviews',
#  'star_rating',
#  'summary',
#  'url']

# %%
books.printSchema()
# Out:
# root
#  |-- _id: string (nullable = true)
#  |-- about_author: string (nullable = true)
#  |-- author: string (nullable = true)
#  |-- community_reviews: string (nullable = true)
#  |-- first_published: string (nullable = true)
#  |-- genres: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- kindle_price: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- num_ratings: integer (nullable = true)
#  |-- num_reviews: double (nullable = true)
#  |-- star_rating: double (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- url: string (nullable = true)

# %% [markdown]
# # <font color='#BFD72F' size=6>**3. Preprocessing**</font> <a class="anchor" id="3"></a>
#
# [Back to TOC](#toc)

# %% [markdown]
# ## <font color='#BFD72F' size=6>3.1 Cleaning and Normalizing MongoDB-Exported Fields in a PySpark DataFrame </font> <a class="anchor" id="3_1"></a>
#
# [Back to TOC](#toc)

# %%
# Step 1: force to string
books = books.withColumn(
    "kindle_price",
    F.col("kindle_price").cast("string")
)

# Step 2: extract from {"$numberDouble": "..."}
clean_price = (
    F.when(
        F.col("kindle_price").rlike(r'\$numberDouble'),
        F.regexp_extract("kindle_price", r'"\$numberDouble":\s*"([^"]+)"', 1)
    )
    .otherwise(F.col("kindle_price"))
)

# Step 3: remove $ and quotes
clean_price2 = F.regexp_replace(clean_price, r'[$"]', "")

books = books.withColumn("kindle_price", clean_price2)

# Step 4: manual NULLIF equivalent
books = books.withColumn(
    "kindle_price",
    F.when(F.col("kindle_price") == "", None).otherwise(F.col("kindle_price"))
)


books = books.withColumn(
    "genres",
    F.regexp_replace("genres", r'\{\s*"\$numberDouble"\s*:\s*"[^"]*"\s*\}', "")
)

books = (
    books
    # 1. Remove MongoDB {"$numberDouble": "NaN"}
    .withColumn(
        "first_published",
        F.regexp_replace("first_published", r'\{\s*"\$numberDouble"\s*:\s*"[^"]*"\s*\}', "")
    )
    # 3. Convert empty strings or obviously invalid strings to NULL
    .withColumn(
        "first_published",
        F.when(F.col("first_published").rlike(r'^\d{1,2}/\d{1,2}/\d{4}$'), F.col("first_published"))
         .otherwise(None)
    )
    # 4. Safely convert valid strings to date
    .withColumn(
        "first_published",
        F.to_date("first_published", "M/d/yyyy")
    )
)

# %%
books.select("community_reviews").show(truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |community_reviews                                                                                                                                                                                                                                                      |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":1,"reviews_percentage":14},"4_stars":{"reviews_num":3,"reviews_percentage":42},"5_stars":{"reviews_num":3,"reviews_percentage":42}}    |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":1,"reviews_percentage":100},"4_stars":{"reviews_num":0,"reviews_percentage":0},"5_stars":{"reviews_num":0,"reviews_percentage":0}}     |
# |{"1_stars":{"reviews_num":1,"reviews_percentage":50},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":0,"reviews_percentage":0},"4_stars":{"reviews_num":0,"reviews_percentage":0},"5_stars":{"reviews_num":1,"reviews_percentage":50}}     |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":6,"reviews_percentage":6},"3_stars":{"reviews_num":12,"reviews_percentage":13},"4_stars":{"reviews_num":29,"reviews_percentage":32},"5_stars":{"reviews_num":41,"reviews_percentage":46}} |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":1,"reviews_percentage":16},"4_stars":{"reviews_num":1,"reviews_percentage":16},"5_stars":{"reviews_num":4,"reviews_percentage":66}}    |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":0,"reviews_percentage":0},"4_stars":{"reviews_num":1,"reviews_percentage":100},"5_stars":{"reviews_num":0,"reviews_percentage":0}}     |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":0,"reviews_percentage":0},"4_stars":{"reviews_num":5,"reviews_percentage":62},"5_stars":{"reviews_num":3,"reviews_percentage":37}}     |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":0,"reviews_percentage":0},"4_stars":{"reviews_num":1,"reviews_percentage":50},"5_stars":{"reviews_num":1,"reviews_percentage":50}}     |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":1,"reviews_percentage":11},"3_stars":{"reviews_num":3,"reviews_percentage":33},"4_stars":{"reviews_num":4,"reviews_percentage":44},"5_stars":{"reviews_num":1,"reviews_percentage":11}}   |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":1,"reviews_percentage":20},"3_stars":{"reviews_num":2,"reviews_percentage":40},"4_stars":{"reviews_num":2,"reviews_percentage":40},"5_stars":{"reviews_num":0,"reviews_percentage":0}}    |
# |{"1_stars":{"reviews_num":1,"reviews_percentage":9},"2_stars":{"reviews_num":2,"reviews_percentage":18},"3_stars":{"reviews_num":5,"reviews_percentage":45},"4_stars":{"reviews_num":3,"reviews_percentage":27},"5_stars":{"reviews_num":0,"reviews_percentage":0}}    |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":0,"reviews_percentage":0},"4_stars":{"reviews_num":0,"reviews_percentage":0},"5_stars":{"reviews_num":0,"reviews_percentage":0}}       |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":0,"reviews_percentage":0},"4_stars":{"reviews_num":0,"reviews_percentage":0},"5_stars":{"reviews_num":1,"reviews_percentage":100}}     |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":0,"reviews_percentage":0},"4_stars":{"reviews_num":1,"reviews_percentage":50},"5_stars":{"reviews_num":1,"reviews_percentage":50}}     |
# |{"1_stars":{"reviews_num":2,"reviews_percentage":2},"2_stars":{"reviews_num":9,"reviews_percentage":10},"3_stars":{"reviews_num":35,"reviews_percentage":41},"4_stars":{"reviews_num":26,"reviews_percentage":30},"5_stars":{"reviews_num":13,"reviews_percentage":15}}|
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":0,"reviews_percentage":0},"4_stars":{"reviews_num":0,"reviews_percentage":0},"5_stars":{"reviews_num":1,"reviews_percentage":100}}     |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":0,"reviews_percentage":0},"3_stars":{"reviews_num":0,"reviews_percentage":0},"4_stars":{"reviews_num":0,"reviews_percentage":0},"5_stars":{"reviews_num":0,"reviews_percentage":0}}       |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":6,"reviews_percentage":16},"3_stars":{"reviews_num":17,"reviews_percentage":45},"4_stars":{"reviews_num":12,"reviews_percentage":32},"5_stars":{"reviews_num":2,"reviews_percentage":5}}  |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":1,"reviews_percentage":4},"3_stars":{"reviews_num":1,"reviews_percentage":4},"4_stars":{"reviews_num":6,"reviews_percentage":28},"5_stars":{"reviews_num":13,"reviews_percentage":61}}    |
# |{"1_stars":{"reviews_num":0,"reviews_percentage":0},"2_stars":{"reviews_num":7,"reviews_percentage":14},"3_stars":{"reviews_num":27,"reviews_percentage":57},"4_stars":{"reviews_num":9,"reviews_percentage":19},"5_stars":{"reviews_num":4,"reviews_percentage":8}}   |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
numerical_cols = [
    'num_ratings',
    'num_reviews',
    'star_rating',
    'kindle_price'
]

integer_cols = [
    'num_ratings',
    'num_reviews',
    'star_rating'
]

float_cols = [
    'kindle_price'
]

date_cols = [
    'first_published'
]

# %%
# Define schema for the JSON in about_author
schema = StructType([
    StructField("name", StringType(), True),
    StructField("num_books", IntegerType(), True),
    StructField("num_followers", StringType(), True),  # string → later cast to int
])

# Parse JSON and extract fields into new columns
books = (
    books
    .withColumn("about_author_json", F.from_json("about_author", schema))
    .withColumn("author_name", F.col("about_author_json.name"))
    .withColumn("author_num_books", F.col("about_author_json.num_books"))
    .withColumn(
        "author_num_followers",
        F.col("about_author_json.num_followers").cast("int")
    )
    .drop("about_author_json")   # optional: removes temp parsed struct
)

schema1 = StructType([
    StructField("", StringType(), True),
    StructField("num_books", IntegerType(), True),
    StructField("num_followers", StringType(), True),  # string → later cast to int
])

# Parse JSON and extract fields into new columns
books = (
    books
    .withColumn("about_author_json", F.from_json("about_author", schema))
    .withColumn("author_name", F.col("about_author_json.name"))
    .withColumn("author_num_books", F.col("about_author_json.num_books"))
    .withColumn(
        "author_num_followers",
        F.col("about_author_json.num_followers").cast("int")
    )
    .drop("about_author_json")   # optional: removes temp parsed struct
)

books = books.drop("url", "summary", "author", "about_author")

numerical_cols += ["author_num_books", "author_num_followers"]
integer_cols += ["author_num_books", "author_num_followers"]
#see what to do with 'community_review' column

# %%
from pyspark.sql.types import *

community_schema = StructType([
    StructField("1_stars", StructType([
        StructField("reviews_num", IntegerType()),
        StructField("reviews_percentage", IntegerType())
    ])),
    StructField("2_stars", StructType([
        StructField("reviews_num", IntegerType()),
        StructField("reviews_percentage", IntegerType())
    ])),
    StructField("3_stars", StructType([
        StructField("reviews_num", IntegerType()),
        StructField("reviews_percentage", IntegerType())
    ])),
    StructField("4_stars", StructType([
        StructField("reviews_num", IntegerType()),
        StructField("reviews_percentage", IntegerType())
    ])),
    StructField("5_stars", StructType([
        StructField("reviews_num", IntegerType()),
        StructField("reviews_percentage", IntegerType())
    ])),
])

books = books.withColumn(
    "community_json",
    F.from_json("community_reviews", community_schema)
)

books = (
    books
    .withColumn("community_reviews_1_star", F.col("community_json.`1_stars`.reviews_num"))
    .withColumn("community_reviews_2_star", F.col("community_json.`2_stars`.reviews_num"))
    .withColumn("community_reviews_3_star", F.col("community_json.`3_stars`.reviews_num"))
    .withColumn("community_reviews_4_star", F.col("community_json.`4_stars`.reviews_num"))
    .withColumn("community_reviews_5_star", F.col("community_json.`5_stars`.reviews_num"))
    .drop("community_json")   # cleanup
)

books = books.drop("community_reviews")

# %% [markdown]
# ## <font color='#BFD72F' size=6>3.2 Correcting the dataypes of some columns</font> <a class="anchor" id="3_2"></a>
#
# [Back to TOC](#toc)

# %%
show_column_types(books)
# Out:
# Column Name - Data Type
# ------------------------------
# _id - string
# first_published - date
# genres - string
# id - string
# kindle_price - string
# name - string
# num_ratings - int
# num_reviews - double
# star_rating - double
# author_name - string
# author_num_books - int
# author_num_followers - int
# community_reviews_1_star - int
# community_reviews_2_star - int
# community_reviews_3_star - int
# community_reviews_4_star - int
# community_reviews_5_star - int

# %%
books = transform_type(books, integer_cols, "int")
books = transform_type(books, float_cols, "float")
books = transform_type(books, date_cols, "date")

# %%
books.show()
# Out:
# [Stage 2:>                                                          (0 + 1) / 1]
# +--------------------+---------------+--------------------+--------------------+------------+--------------------+-----------+-----------+-----------+--------------------+----------------+--------------------+------------------------+------------------------+------------------------+------------------------+------------------------+
# |                 _id|first_published|              genres|                  id|kindle_price|                name|num_ratings|num_reviews|star_rating|         author_name|author_num_books|author_num_followers|community_reviews_1_star|community_reviews_2_star|community_reviews_3_star|community_reviews_4_star|community_reviews_5_star|
# +--------------------+---------------+--------------------+--------------------+------------+--------------------+-----------+-----------+-----------+--------------------+----------------+--------------------+------------------------+------------------------+------------------------+------------------------+------------------------+
# |69122a00adb7d57eb...|     1991-11-01|                    |1047836.Horror_Fi...|         NaN|Horror Film Direc...|          7|       NULL|          4|      Dennis Fischer|              14|                NULL|                       0|                       0|                       1|                       3|                       3|
# |69122a00adb7d57eb...|     2000-02-01|                    |4089333-australia...|         NaN|Australian Urban ...|          1|       NULL|          3|     Brendan Gleeson|              28|                NULL|                       0|                       0|                       1|                       0|                       0|
# |69122a00adb7d57eb...|     2015-09-18|                    |26764878-morgen-o...|       10.89|Morgen ohne geste...|          2|       NULL|          3|      Regina Nössler|              28|                   1|                       1|                       0|                       0|                       0|                       1|
# |69122a00adb7d57eb...|     2014-10-01|["Music","Nonfict...|23656944-zen-and-...|       24.09|Zen and the Art o...|         88|          4|          4|            Mixerman|              15|                  36|                       0|                       6|                      12|                      29|                      41|
# |69122a00adb7d57eb...|     2015-09-05|                    |26761586-the-big-...|         NaN|The Big Book Of C...|          6|       NULL|          4|      Parragon Books|            6068|                  67|                       0|                       0|                       1|                       1|                       4|
# |69122a00adb7d57eb...|     2016-09-01|                    |32471492-antique-...|         NaN|Antique Apples fr...|          1|       NULL|          4|Phyllis Bye Kilch...|               1|                NULL|                       0|                       0|                       0|                       1|                       0|
# |69122a00adb7d57eb...|     2016-09-26|                    |32476267-it-s-a-w...|         NaN|It's A Wonderful ...|          8|          4|          4|         Derek Beebe|               7|                   7|                       0|                       0|                       0|                       5|                       3|
# |69122a00adb7d57eb...|     1977-05-12|                    |4201989-an-introd...|         NaN|An Introduction t...|          2|       NULL|          4|       H. Van Olphen|              10|                NULL|                       0|                       0|                       0|                       1|                       1|
# |69122a00adb7d57eb...|     2000-03-30|         ["History"]|4103828-oman-unde...|       78.84|   Oman Under Qaboos|          9|       NULL|          3|     Calvin H. Allen|               4|                NULL|                       0|                       1|                       3|                       4|                       1|
# |69122a00adb7d57eb...|     2007-04-30|        ["Quilting"]|317587.Quilts_Fro...|       22.99|Quilts From Laven...|          5|       NULL|          3|   Darlene Zimmerman|              23|                   1|                       0|                       1|                       2|                       2|                       0|
# |69122a00adb7d57eb...|     1931-01-01|                    |9845417-murder-of...|         NaN|Murder of the Cle...|         11|          3|          2|       Anthony Abbot|              36|                   1|                       1|                       2|                       5|                       3|                       0|
# |69122a00adb7d57eb...|     2008-12-01|                    |            19235540|        3.99|塔木德大全集(珍藏版)|          0|       NULL|          0|              柯友辉|              24|                NULL|                       0|                       0|                       0|                       0|                       0|
# |69122a00adb7d57eb...|     2007-01-01|                    |19204805-osnove-m...|         NaN|   Osnove marketinga|          1|       NULL|          5|       Jozo Previšić|               2|                   1|                       0|                       0|                       0|                       0|                       1|
# |69122a00adb7d57eb...|     1962-01-01|                    |28806739-tierra-i...|         NaN|       Tierra Inerme|          2|       NULL|          4|         Dora Alonso|              25|                   3|                       0|                       0|                       0|                       1|                       1|
# |69122a00adb7d57eb...|     2002-01-28|["Art","History",...|   318028.Il_Gigante|       11.99|Il Gigante: Miche...|         85|         12|          3|          Anton Gill|              57|                  60|                       2|                       9|                      35|                      26|                      13|
# |69122a00adb7d57eb...|     1998-01-01|                    |28801173-practica...|         NaN|Practical Lessons...|          1|       NULL|          5|   Percival Marshall|              60|                   1|                       0|                       0|                       0|                       0|                       1|
# |69122a00adb7d57eb...|     2015-09-22|                    |26808089-ok-cupid...|       29.99|Ok Cupid Dating S...|          0|       NULL|          0|       Seventy Seven|              17|                   1|                       0|                       0|                       0|                       0|                       0|
# |69122a00adb7d57eb...|     2017-05-02|                    |35050700-g-tenmor...|         NaN|Gūtenmorgens. Otr...|         37|          7|          3|       Māris Bērziņš|              17|                  18|                       0|                       6|                      17|                      12|                       2|
# |69122a00adb7d57eb...|     1981-01-01|          ["Poetry"]|6590893-verzameld...|         NaN|Verzamelde Gedichten|         21|       NULL|          4|       Jotie T'Hooft|              16|                  21|                       0|                       1|                       1|                       6|                      13|
# |69122a00adb7d57eb...|     2005-06-14|["Nonfiction","Fa...|313435.Sam_Sabour...|         NaN|Sam Saboura's Rea...|         47|         10|          3|         Sam Saboura|               1|                   5|                       0|                       7|                      27|                       9|                       4|
# +--------------------+---------------+--------------------+--------------------+------------+--------------------+-----------+-----------+-----------+--------------------+----------------+--------------------+------------------------+------------------------+------------------------+------------------------+------------------------+
# only showing top 20 rows

# %%
show_column_types(books)
# Out:
# Column Name - Data Type
# ------------------------------
# _id - string
# first_published - date
# genres - string
# id - string
# kindle_price - float
# name - string
# num_ratings - int
# num_reviews - int
# star_rating - int
# author_name - string
# author_num_books - int
# author_num_followers - int
# community_reviews_1_star - int
# community_reviews_2_star - int
# community_reviews_3_star - int
# community_reviews_4_star - int
# community_reviews_5_star - int

# %% [markdown]
# ## <font color='#BFD72F' size=6>3.3 Transform genres to array</font> <a class="anchor" id="3_3"></a>
#
# [Back to TOC](#toc)

# %%
books = books.withColumn(
    "genres_array",
    F.split(
        F.regexp_replace(
            F.col("genres"),
            r'[\[\]"]',   # remove [ ] and "
            ""
        ),
        r"\s*,\s*"      # split on commas cleanly
    )
)

# %%
books.show()
# Out:
# [Stage 3:>                                                          (0 + 1) / 1]
# +--------------------+---------------+--------------------+--------------------+------------+--------------------+-----------+-----------+-----------+--------------------+----------------+--------------------+------------------------+------------------------+------------------------+------------------------+------------------------+--------------------+
# |                 _id|first_published|              genres|                  id|kindle_price|                name|num_ratings|num_reviews|star_rating|         author_name|author_num_books|author_num_followers|community_reviews_1_star|community_reviews_2_star|community_reviews_3_star|community_reviews_4_star|community_reviews_5_star|        genres_array|
# +--------------------+---------------+--------------------+--------------------+------------+--------------------+-----------+-----------+-----------+--------------------+----------------+--------------------+------------------------+------------------------+------------------------+------------------------+------------------------+--------------------+
# |69122a00adb7d57eb...|     1991-11-01|                    |1047836.Horror_Fi...|         NaN|Horror Film Direc...|          7|       NULL|          4|      Dennis Fischer|              14|                NULL|                       0|                       0|                       1|                       3|                       3|                  []|
# |69122a00adb7d57eb...|     2000-02-01|                    |4089333-australia...|         NaN|Australian Urban ...|          1|       NULL|          3|     Brendan Gleeson|              28|                NULL|                       0|                       0|                       1|                       0|                       0|                  []|
# |69122a00adb7d57eb...|     2015-09-18|                    |26764878-morgen-o...|       10.89|Morgen ohne geste...|          2|       NULL|          3|      Regina Nössler|              28|                   1|                       1|                       0|                       0|                       0|                       1|                  []|
# |69122a00adb7d57eb...|     2014-10-01|["Music","Nonfict...|23656944-zen-and-...|       24.09|Zen and the Art o...|         88|          4|          4|            Mixerman|              15|                  36|                       0|                       6|                      12|                      29|                      41| [Music, Nonfiction]|
# |69122a00adb7d57eb...|     2015-09-05|                    |26761586-the-big-...|         NaN|The Big Book Of C...|          6|       NULL|          4|      Parragon Books|            6068|                  67|                       0|                       0|                       1|                       1|                       4|                  []|
# |69122a00adb7d57eb...|     2016-09-01|                    |32471492-antique-...|         NaN|Antique Apples fr...|          1|       NULL|          4|Phyllis Bye Kilch...|               1|                NULL|                       0|                       0|                       0|                       1|                       0|                  []|
# |69122a00adb7d57eb...|     2016-09-26|                    |32476267-it-s-a-w...|         NaN|It's A Wonderful ...|          8|          4|          4|         Derek Beebe|               7|                   7|                       0|                       0|                       0|                       5|                       3|                  []|
# |69122a00adb7d57eb...|     1977-05-12|                    |4201989-an-introd...|         NaN|An Introduction t...|          2|       NULL|          4|       H. Van Olphen|              10|                NULL|                       0|                       0|                       0|                       1|                       1|                  []|
# |69122a00adb7d57eb...|     2000-03-30|         ["History"]|4103828-oman-unde...|       78.84|   Oman Under Qaboos|          9|       NULL|          3|     Calvin H. Allen|               4|                NULL|                       0|                       1|                       3|                       4|                       1|           [History]|
# |69122a00adb7d57eb...|     2007-04-30|        ["Quilting"]|317587.Quilts_Fro...|       22.99|Quilts From Laven...|          5|       NULL|          3|   Darlene Zimmerman|              23|                   1|                       0|                       1|                       2|                       2|                       0|          [Quilting]|
# |69122a00adb7d57eb...|     1931-01-01|                    |9845417-murder-of...|         NaN|Murder of the Cle...|         11|          3|          2|       Anthony Abbot|              36|                   1|                       1|                       2|                       5|                       3|                       0|                  []|
# |69122a00adb7d57eb...|     2008-12-01|                    |            19235540|        3.99|塔木德大全集(珍藏版)|          0|       NULL|          0|              柯友辉|              24|                NULL|                       0|                       0|                       0|                       0|                       0|                  []|
# |69122a00adb7d57eb...|     2007-01-01|                    |19204805-osnove-m...|         NaN|   Osnove marketinga|          1|       NULL|          5|       Jozo Previšić|               2|                   1|                       0|                       0|                       0|                       0|                       1|                  []|
# |69122a00adb7d57eb...|     1962-01-01|                    |28806739-tierra-i...|         NaN|       Tierra Inerme|          2|       NULL|          4|         Dora Alonso|              25|                   3|                       0|                       0|                       0|                       1|                       1|                  []|
# |69122a00adb7d57eb...|     2002-01-28|["Art","History",...|   318028.Il_Gigante|       11.99|Il Gigante: Miche...|         85|         12|          3|          Anton Gill|              57|                  60|                       2|                       9|                      35|                      26|                      13|[Art, History, Ar...|
# |69122a00adb7d57eb...|     1998-01-01|                    |28801173-practica...|         NaN|Practical Lessons...|          1|       NULL|          5|   Percival Marshall|              60|                   1|                       0|                       0|                       0|                       0|                       1|                  []|
# |69122a00adb7d57eb...|     2015-09-22|                    |26808089-ok-cupid...|       29.99|Ok Cupid Dating S...|          0|       NULL|          0|       Seventy Seven|              17|                   1|                       0|                       0|                       0|                       0|                       0|                  []|
# |69122a00adb7d57eb...|     2017-05-02|                    |35050700-g-tenmor...|         NaN|Gūtenmorgens. Otr...|         37|          7|          3|       Māris Bērziņš|              17|                  18|                       0|                       6|                      17|                      12|                       2|                  []|
# |69122a00adb7d57eb...|     1981-01-01|          ["Poetry"]|6590893-verzameld...|         NaN|Verzamelde Gedichten|         21|       NULL|          4|       Jotie T'Hooft|              16|                  21|                       0|                       1|                       1|                       6|                      13|            [Poetry]|
# |69122a00adb7d57eb...|     2005-06-14|["Nonfiction","Fa...|313435.Sam_Sabour...|         NaN|Sam Saboura's Rea...|         47|         10|          3|         Sam Saboura|               1|                   5|                       0|                       7|                      27|                       9|                       4|[Nonfiction, Fash...|
# +--------------------+---------------+--------------------+--------------------+------------+--------------------+-----------+-----------+-----------+--------------------+----------------+--------------------+------------------------+------------------------+------------------------+------------------------+------------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## <font color='#BFD72F' size=6>3.4 Filtering our dataset between 1500 and 2025</font> <a class="anchor" id="3_4"></a>
#
# [Back to TOC](#toc)

# %%
#books.select("first_published", "id", "name").show(20, truncate=False)
# Show the oldest books first
books.select("first_published", "name") \
     .orderBy(F.asc_nulls_last("first_published")) \
     .show(100, truncate=False)
# Out:
# [Stage 4:===================================================>       (7 + 1) / 8]
# +---------------+------------------------------------------------------------------------------------------------------------------------------------+
# |first_published|name                                                                                                                                |
# +---------------+------------------------------------------------------------------------------------------------------------------------------------+
# |1000-01-01     |My Own Teams: The Bill Reidy Story                                                                                                  |
# |1000-01-01     |Cultural Anthropology                                                                                                               |
# |1000-01-01     |Dear America: The Winter of Red Snow, A Line in the Sand, A Light in the Storm, When Will This Cruel War Be Over?                   |
# |1000-01-01     |The Tale of Lady Ochikubo                                                                                                           |
# |1000-01-01     |New Yorker Nurse                                                                                                                    |
# |1010-01-01     |Skywriting in the Minor Key: women words wings.                                                                                     |
# |1010-10-01     |The Monster: How a Gang of Predatory Lenders and Wall Street Bankers Fleeced America--and Spawned a Global Crisis                   |
# |1013-10-03     |Plant Life of Palestine: Israel and Jordan                                                                                          |
# |1015-05-15     |Who tests the tester - New Approach?                                                                                                |
# |1030-01-01     |تحقيق ما للهند من مقولة مقبولة في العقل أو مرذولة                                                                                   |
# |1030-01-01     |Iniziazione: Kalacakra                                                                                                              |
# |1033-01-01     |The Epistle of Forgiveness, or A Pardon to Enter the Garden                                                                         |
# |1050-01-01     |Michael Psellus on the Operation of Daemons                                                                                         |
# |1074-01-01     |The Concept of Śraddhā in the Brāhmaṇas, Upaniṣads and the Gītā                                                                     |
# |1078-01-01     |Fourteen Byzantine Rulers: The Chronographia of Michael Psellus                                                                     |
# |1090-01-01     |Cur Deus Homo                                                                                                                       |
# |1100-01-01     |A Compost Kind of Girl: Chronicles of an Amateur Gardener                                                                           |
# |1114-01-01     |سوانح                                                                                                                               |
# |1140-01-01     |The Kuzari: An Argument for the Faith of Israel                                                                                     |
# |1154-01-01     |Writings Against the Saracens                                                                                                       |
# |1168-01-01     |The Procession of the World                                                                                                         |
# |1170-01-01     |The Romance of Tristan and Iseult                                                                                                   |
# |1183-01-01     |Raoul de Cambrai                                                                                                                    |
# |1186-01-01     |Meilės žiedas, arba trys knygos apie meilę                                                                                          |
# |1193-01-01     |Laughter Is An Egg                                                                                                                  |
# |1200-01-01     |The Saga of the Jómsvíkings                                                                                                         |
# |1200-01-01     |Saga di Oddr l'Arciere                                                                                                              |
# |1200-01-01     |De vertellingen van duizend en één nacht, deel 9/10                                                                                 |
# |1200-01-01     |Fergus of Galloway: Knight of King Arthur                                                                                           |
# |1201-06-01     |Rebel in the Soul: A Dialogue Between Doubt and Mystical Knowledge                                                                  |
# |1213-01-01     |The Song of the Cathar Wars: A History of the Albigensian Crusade                                                                   |
# |1220-01-01     |Heimskringla; Or, the Chronicle of the Kings of Norway, Volume II                                                                   |
# |1220-01-01     |Lancelot of the Lake                                                                                                                |
# |1225-01-01     |Lancelot du Lac III : La Fausse Guenièvre                                                                                           |
# |1235-01-01     |One Hundred Leaves: A new annotated translation of the Hyakunin Isshu                                                               |
# |1243-01-01     |Historia de los Hechos de España                                                                                                    |
# |1250-01-01     |The Rise of Gawain, Nephew of Arthur: De Ortu Waluuanii Nepotis Arturi                                                              |
# |1258-01-01     |Faith, Reason and Theology                                                                                                          |
# |1266-01-01     |Poema de Fernán González . (ODRES NUEVOS. O/N.)                                                                                     |
# |1270-01-01     |Roman van Walewein                                                                                                                  |
# |1270-01-01     |Disputed Questions on the Soul                                                                                                      |
# |1270-01-03     |The Masnavi: Book Three                                                                                                             |
# |1273-01-01     |Summa Theologica, Part III (Tertia Pars) From the Complete American Edition                                                         |
# |1283-01-01     |Blanquerna                                                                                                                          |
# |1288-01-01     |De magnalibus Mediolani - Le meraviglie di Milano                                                                                   |
# |1290-01-01     |The Book of Secrets of Albertus Magnus: Of the Virtues of Herbs, Stones, and Certain Beasts, Also a Book of the Marvels of the World|
# |1300-01-01     |Fóstbrædra-saga: edr, Sagan af Þorgeiri Havarssyni ok Þormódi Bersasyni Kolbrúnarskalldi                                            |
# |1323-01-01     |Summe Der Logik: Aus Teil I, Über Die Termini                                                                                       |
# |1336-01-01     |سفینه غزل                                                                                                                           |
# |1340-01-01     |فکر آزادی و مقدمه نهضت مشروطیت                                                                                                      |
# |1344-01-01     |The Love of Books: The Philobiblon of Richard de Bury                                                                               |
# |1350-01-01     |Lanseloet van Denemerken                                                                                                            |
# |1350-01-01     |El juego del ajedrez o Dechado de Fortuna                                                                                           |
# |1350-01-01     |Harðar saga                                                                                                                         |
# |1351-01-01     |با تشنگی پیر می‌شویم                                                                                                                |
# |1351-01-01     |رستم و اسفندیار در شاهنامه                                                                                                          |
# |1352-01-01     |آرزو                                                                                                                                |
# |1352-01-01     |سرمایه داری امریکا                                                                                                                  |
# |1354-01-01     |ادبیات دوره ی بیداری و معاصر                                                                                                        |
# |1355-01-01     |كتاب الآثار                                                                                                                         |
# |1358-01-01     |Petrarch’s Guide to the Holy Land: Itinerary to the Sepulcher of Our Lord Jesus Christ                                              |
# |1358-01-01     |مردم و فردوسی                                                                                                                       |
# |1360-01-01     |Three Kingdoms II of IV                                                                                                             |
# |1360-01-01     |Histoire des Trois Royaumes - Tome I                                                                                                |
# |1361-01-01     |شرح ابن عقیل - المجلد الاول                                                                                                         |
# |1362-01-01     |The Spanish-Cuban-American War (Birth of Imperialism) / Volume 1                                                                    |
# |1365-01-01     |ثمرات الأوراق                                                                                                                       |
# |1366-01-01     |فیزیک، جلد اول                                                                                                                      |
# |1367-01-01     |رسم الخط نستعلیق آسان                                                                                                               |
# |1368-01-01     |Dream Visions and Other Poems                                                                                                       |
# |1369-01-01     |زندگی سیاسی سید ضیاء الدین طباطبایی                                                                                                 |
# |1370-01-01     |امپراتور سیب‌زمینی چهارم                                                                                                            |
# |1371-01-01     |هنر سخن گفتن                                                                                                                        |
# |1372-01-01     |آیه‌های ایرانی                                                                                                                      |
# |1372-01-01     |The Wife of Bath                                                                                                                    |
# |1372-01-01     |ده شاعر نامدار قرن بیستم                                                                                                            |
# |1372-01-01     |خارهای الجزایر                                                                                                                      |
# |1372-01-01     |آیین زروانی                                                                                                                         |
# |1373-01-01     |بوسه به باران                                                                                                                       |
# |1373-01-01     |Lawaeh                                                                                                                              |
# |1374-01-01     |جناب سیب منتظر نیوتن بود                                                                                                            |
# |1374-01-01     |ماجرای پایان ناپذیر حافظ                                                                                                            |
# |1374-01-01     |سر گشتگی نشانه‌ها                                                                                                                   |
# |1374-01-01     |سه منظومه                                                                                                                           |
# |1375-01-01     |The Hafez Poems                                                                                                                     |
# |1375-01-01     |Chaucer's Boece: A Critical Edition Based on Cambridge University Library MS.                                                       |
# |1376-01-01     |paris in renout                                                                                                                     |
# |1376-01-01     |از دیدار خویشتن / یادداشت هایی از و در باره ی احسان طبری                                                                            |
# |1376-01-01     |Miroir Historial [Speculum historiale] vol. V. Livres XVII-XX                                                                       |
# |1377-01-01     |نامه‌های عين القضات همدانی- سه مجلد                                                                                                 |
# |1377-01-01     |شعرای بزرگ معاصر ژاپن                                                                                                               |
# |1377-01-01     |Virgil                                                                                                                              |
# |1377-01-01     |بازتاب اسطوره در بوف کور                                                                                                            |
# |1377-01-01     |بچه هاليوود                                                                                                                         |
# |1377-01-01     |برداشتهایی از سیره امام خمینی ، جلد دوم ، ویژگی های فردی                                                                            |
# |1377-01-01     |دو رساله ي عرفاني در عشق- السوانح في العشق و رساله در عشق                                                                           |
# |1378-01-01     |4 مهارت های زندگی                                                                                                                   |
# |1378-01-01     |کودتای28مرداد1332 و رویدادهای متعاقب ان                                                                                             |
# |1378-01-01     |ساختارهای قدرت   درآمدی بر علم سیاست                                                                                                |
# |1378-01-01     |تختي                                                                                                                                |
# +---------------+------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 100 rows

# %%
#see porpotion
books = books.filter((F.year("first_published") > 1979) & (F.year('first_published') <= 2025))

# %%
books_with_year = books.withColumn("year", F.year("first_published"))

# Passing an empty one prevents a second set of "Validation" bars from appearing.
empty_df = books_with_year.limit(0)

# 3. Plot
bar_plots_spark(books_with_year, empty_df, ["year"])

# %%
books.persist(StorageLevel.MEMORY_AND_DISK)
# Out:
# DataFrame[_id: string, first_published: date, genres: string, id: string, kindle_price: float, name: string, num_ratings: int, num_reviews: int, star_rating: int, author_name: string, author_num_books: int, author_num_followers: int, community_reviews_1_star: int, community_reviews_2_star: int, community_reviews_3_star: int, community_reviews_4_star: int, community_reviews_5_star: int, genres_array: array<string>]

# %%
print(f"Data cached: {books.count()} rows")

# %% [markdown]
# ## <font color='#BFD72F' size=6>3.4 Complete exploration</font> <a class="anchor" id="3_4"></a>
#
# [Back to TOC](#toc)

# %%
books.select(
    [
        F.when(F.isnan(F.col(c)), None).otherwise(F.col(c)).alias(c) 
        for c in numerical_cols
    ]
).describe().show()
# Out:
# 25/12/11 12:49:09 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 13:==================================================>       (7 + 1) / 8]
# +-------+------------------+-----------------+------------------+------------------+------------------+--------------------+
# |summary|       num_ratings|      num_reviews|       star_rating|      kindle_price|  author_num_books|author_num_followers|
# +-------+------------------+-----------------+------------------+------------------+------------------+--------------------+
# |  count|            301553|           149745|            301553|            114992|            300757|              210062|
# |   mean|249.72434033155034|35.69217670039066|3.1555447964371104|13.853971425551654| 3120.474638994271|   703.3742180879931|
# | stddev|10853.252553131606|608.5100653991196|1.3107513469886887|26.513561979876606|39256.485346963826|  11921.352214762293|
# |    min|                 0|                0|                 0|               0.0|                 1|                 -14|
# |    max|           3314374|            95985|                 5|             930.0|           3872884|              849475|
# +-------+------------------+-----------------+------------------+------------------+------------------+--------------------+

# %%
books.select("genres").distinct().show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------+
# |genres                                                                                                                                          |
# +------------------------------------------------------------------------------------------------------------------------------------------------+
# |["Art","History","Art History","Italy","Biography","Nonfiction"]                                                                                |
# |["Sports","Football","Nonfiction","Journalism","Biography"]                                                                                     |
# |["Classics","Philosophy","History","Biography"]                                                                                                 |
# |["Comics"]                                                                                                                                      |
# |["Fiction","Contemporary"]                                                                                                                      |
# |["Politics","Nonfiction","Essays"]                                                                                                              |
# |["Horror"]                                                                                                                                      |
# |["M M Romance","Young Adult","LGBT","Romance","Contemporary","Coming Of Age","Gay","Bisexual","Queer","Teen"]                                   |
# |["Libya"]                                                                                                                                       |
# |["New Adult","Romance","Contemporary Romance","Interracial Romance","Contemporary"]                                                             |
# |["Short Stories","Science Fiction","Fantasy"]                                                                                                   |
# |["Mystery","Fiction","Canada","Mystery Thriller"]                                                                                               |
# |["Mystery","Historical Fiction","Egypt","Historical Mystery","Fiction","Historical","Ancient","Africa","Novels","Mystery Thriller"]             |
# |["Marriage","Christian","Relationships","Nonfiction","Christian Non Fiction","Christianity","Sexuality","Counselling","Faith","Religion"]       |
# |["Comics","Bande Dessinée"]                                                                                                                     |
# |["Light Novel"]                                                                                                                                 |
# |["Psychology","Fiction"]                                                                                                                        |
# |["Interracial Romance","Paranormal","Erotica","Paranormal Romance","Shapeshifters","Werewolves","Fantasy","Romance","Short Stories","Adult"]    |
# |["Historical Romance","Historical","Historical Fiction","Romance","Scotland","Fantasy","Adult","Paranormal Romance","Paranormal","18th Century"]|
# |["Manga","Graphic Novels","Fantasy","Romance","Young Adult"]                                                                                    |
# +------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
books.groupBy("first_published").count().orderBy(F.desc("count")).show(10)
# Out:
# +---------------+-----+
# |first_published|count|
# +---------------+-----+
# |     2009-01-01| 4403|
# |     2008-01-01| 3699|
# |     2007-01-01| 3406|
# |     2010-01-01| 3346|
# |     2013-01-01| 3335|
# |     2006-01-01| 3172|
# |     2014-01-01| 3062|
# |     2005-01-01| 3025|
# |     2012-01-01| 2957|
# |     2011-01-01| 2956|
# +---------------+-----+
# only showing top 10 rows

# %%
from pyspark.sql.types import StringType, ArrayType, NumericType

def missing_summary(df):
    exprs = []
    for field in df.schema.fields:
        c = field.name
        t = field.dataType
        if isinstance(t, NumericType):
            expr = F.count(F.when(F.col(c).isNull() | F.isnan(F.col(c)), c)).alias(c)
        elif isinstance(t, StringType):
            expr = F.count(F.when(F.col(c).isNull() | (F.col(c) == ""), c)).alias(c)
        elif isinstance(t, ArrayType):
            expr = F.count(F.when(F.col(c).isNull() | (F.size(F.col(c)) == 0), c)).alias(c)
        else:
            expr = F.count(F.when(F.col(c).isNull(), c)).alias(c)
        exprs.append(expr)
    return df.select(*exprs)

missing_summary(books).show()
# Out:
# +---+---------------+------+---+------------+----+-----------+-----------+-----------+-----------+----------------+--------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------+
# |_id|first_published|genres| id|kindle_price|name|num_ratings|num_reviews|star_rating|author_name|author_num_books|author_num_followers|community_reviews_1_star|community_reviews_2_star|community_reviews_3_star|community_reviews_4_star|community_reviews_5_star|genres_array|
# +---+---------------+------+---+------------+----+-----------+-----------+-----------+-----------+----------------+--------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------+
# |  0|              0|218853|  0|      186561|   0|          0|     151808|          0|          0|             796|               91491|                       0|                       0|                       0|                       0|                       0|           0|
# +---+---------------+------+---+------------+----+-----------+-----------+-----------+-----------+----------------+--------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------+

# %%
books=books.filter((col("genres").isNotNull()) & (col("genres") != ""))

# %%
books.show()
# Out:
# +--------------------+---------------+--------------------+--------------------+------------+--------------------+-----------+-----------+-----------+-------------------+----------------+--------------------+------------------------+------------------------+------------------------+------------------------+------------------------+--------------------+
# |                 _id|first_published|              genres|                  id|kindle_price|                name|num_ratings|num_reviews|star_rating|        author_name|author_num_books|author_num_followers|community_reviews_1_star|community_reviews_2_star|community_reviews_3_star|community_reviews_4_star|community_reviews_5_star|        genres_array|
# +--------------------+---------------+--------------------+--------------------+------------+--------------------+-----------+-----------+-----------+-------------------+----------------+--------------------+------------------------+------------------------+------------------------+------------------------+------------------------+--------------------+
# |69122a00adb7d57eb...|     2014-10-01|["Music","Nonfict...|23656944-zen-and-...|       24.09|Zen and the Art o...|         88|          4|          4|           Mixerman|              15|                  36|                       0|                       6|                      12|                      29|                      41| [Music, Nonfiction]|
# |69122a00adb7d57eb...|     2000-03-30|         ["History"]|4103828-oman-unde...|       78.84|   Oman Under Qaboos|          9|       NULL|          3|    Calvin H. Allen|               4|                NULL|                       0|                       1|                       3|                       4|                       1|           [History]|
# |69122a00adb7d57eb...|     2007-04-30|        ["Quilting"]|317587.Quilts_Fro...|       22.99|Quilts From Laven...|          5|       NULL|          3|  Darlene Zimmerman|              23|                   1|                       0|                       1|                       2|                       2|                       0|          [Quilting]|
# |69122a00adb7d57eb...|     2002-01-28|["Art","History",...|   318028.Il_Gigante|       11.99|Il Gigante: Miche...|         85|         12|          3|         Anton Gill|              57|                  60|                       2|                       9|                      35|                      26|                      13|[Art, History, Ar...|
# |69122a00adb7d57eb...|     1981-01-01|          ["Poetry"]|6590893-verzameld...|         NaN|Verzamelde Gedichten|         21|       NULL|          4|      Jotie T'Hooft|              16|                  21|                       0|                       1|                       1|                       6|                      13|            [Poetry]|
# |69122a00adb7d57eb...|     2005-06-14|["Nonfiction","Fa...|313435.Sam_Sabour...|         NaN|Sam Saboura's Rea...|         47|         10|          3|        Sam Saboura|               1|                   5|                       0|                       7|                      27|                       9|                       4|[Nonfiction, Fash...|
# |69122a00adb7d57eb...|     2007-01-01|["True Crime","No...|310054.Final_Anal...|        4.99|Final Analysis: T...|        475|         51|          3|    Catherine Crier|              10|                  95|                      31|                      53|                     177|                     131|                      83|[True Crime, Nonf...|
# |69122a00adb7d57eb...|     1999-03-01|   ["Picture Books"]|485618.Chicken_So...|         NaN|Chicken Soup for ...|         21|          2|          4|       Lisa McCourt|              75|                  31|                       0|                       0|                       0|                       5|                      16|     [Picture Books]|
# |69122a00adb7d57eb...|     2012-05-01|        ["Thriller"]|     13633706-gulzig|         NaN|              Gulzig|         60|          6|          2|        Marion Pauw|              43|                 130|                       2|                      17|                      27|                      14|                       0|          [Thriller]|
# |69122a00adb7d57eb...|     2010-01-01|        ["Business"]|8659397-built-to-...|       27.95|Built to Love: Cr...|         34|          1|          3|   Peter Boatwright|               7|                NULL|                       1|                       5|                      12|                      11|                       5|          [Business]|
# |69122a00adb7d57eb...|     2015-09-21|  ["BDSM","Erotica"]|26802158-her-secr...|        4.99|Her Secret Submis...|         55|          9|          3|   Carolyn Faulkner|             215|                 341|                       1|                       6|                      15|                      14|                      19|     [BDSM, Erotica]|
# |69122a00adb7d57eb...|     1982-08-19|["Physics","Nonfi...|556094.Introducti...|         NaN|Introduction to S...|         32|          1|          3|   Wolfgang Rindler|              11|                  11|                       1|                       1|                       7|                      12|                      11|[Physics, Nonfict...|
# |69122a00adb7d57eb...|     2002-02-25|["History","Nonfi...|542884.Breaking_L...|       16.19|Breaking Loose To...|         77|          7|          3|    Marjoleine Kars|               5|                  12|                       0|                       4|                      19|                      31|                      23|[History, Nonfict...|
# |69122a00adb7d57eb...|     2012-03-01|["Romance","Histo...|26816013-the-bett...|        2.99|  The Betting Season|        375|         18|          3|          Ava Stone|              99|                 229|                       8|                      20|                      97|                     124|                     126|[Romance, Histori...|
# |69122a00adb7d57eb...|     2008-09-08|["Urban Fantasy",...|11552923-children...|         0.0|     Children of Sun|        140|         16|          3|      R.B. Holbrook|               3|                   5|                       6|                       7|                      36|                      47|                      44|[Urban Fantasy, F...|
# |69122a00adb7d57eb...|     1981-03-19|["Military Histor...|492441.The_Armies...|         NaN|The Armies of Cre...|         41|          4|          3|Christopher Rothero|              17|                NULL|                       0|                       2|                      12|                      20|                       7|[Military History...|
# |69122a00adb7d57eb...|     2008-03-04|["Poetry","Classi...|11653021-byron-s-...|         0.0|Byron's Poetical ...|        100|          5|          3|         Lord Byron|            3886|                1905|                       3|                      10|                      20|                      32|                      35|  [Poetry, Classics]|
# |69122a00adb7d57eb...|     2010-05-01|            ["Iran"]|        8653486-iran|        9.95|Iran: My Grandfather|         25|          5|          3|       Ali Alizadeh|              26|                   6|                       0|                       1|                       5|                      16|                       3|              [Iran]|
# |69122a00adb7d57eb...|     2016-01-27|   ["Short Stories"]|28789022-taking-t...|         NaN|Taking the Fall Line|          2|          1|          4|         Tray Ellis|              23|                   4|                       0|                       0|                       1|                       0|                       1|     [Short Stories]|
# |69122a00adb7d57eb...|     2010-09-17|       ["Reference"]|18894022-kindle-p...|        0.49|Kindle Psalms: Th...|         97|          9|          4|          Anonymous|          791444|                3188|                       3|                       1|                       4|                       9|                      80|         [Reference]|
# +--------------------+---------------+--------------------+--------------------+------------+--------------------+-----------+-----------+-----------+-------------------+----------------+--------------------+------------------------+------------------------+------------------------+------------------------+------------------------+--------------------+
# only showing top 20 rows
